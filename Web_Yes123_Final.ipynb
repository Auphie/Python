# %%
import requests
import json
from bs4 import BeautifulSoup

url = "https://www.yes123.com.tw/admin/job_refer_list.asp"
data = json.loads(r'''{
    "find_key1": "java",
    "order_by": "neworder",
    "order_ascend": "desc",
    "search_key_word": "java",
    "search_type": "job",
    "us_menu": "",
    "search_item": "1",
    "search_from": "joblist",
    "job_show_type": "B"
}''')
headers = json.loads(r'''{
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.9",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Content-Length": "4341",
    "Content-Type": "application/x-www-form-urlencoded",
    "Cookie": "_sh_c_1=search_type%3Ajob%7Csearch_item%3A1%7Csearch_key_word%3Ajava%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_2=search_type%3Ajob%7Csearch_item%3A1%7Csearch_key_word%3Ajava%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_3=search_type%3Ajob%7Csearch_item%3A1%7Csearch_key_word%3Ajava%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_4=search_type%3Ajob%7Csearch_item%3A1%7Csearch_key_word%3Ajava%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; _sh_c_5=search_type%3Ajob%7Csearch_item%3A1%7Csearch_key_word%3Ajava%7C_mu_ckb_21%3Acheckbox%7C_mu_ckb_22%3Acheckbox%7C_mu_ckb_23%3Acheckbox%7C_mu_ckb_24%3Acheckbox%7C_mu_ckb_25%3Acheckbox; ASPSESSIONIDSSBTSQRQ=EEDOBPLCADDPFDGFCIBLEGED; __asc=9b3990ed160de388f0fbe417dbf; __auc=9b3990ed160de388f0fbe417dbf; ClientIP=111.248.71.118; _ga=GA1.3.2064806402.1515556737; _gid=GA1.3.25806277.1515556737; yes123_make_cookie=418e272f0d40445d91db71bcc4bdba26; view%5Fjob%5Fid%5Fstr=20140103100924%5F27365925%40%21%4020170202181648%5F8100619%40%21%40D4000+%E5%A4%A7%E6%95%B8%E6%93%9A%E5%B9%B3%E5%8F%B0%E5%B7%A5%E7%A8%8B%E5%B8%AB%28Java%29%24%21%2420111125115316%5F84703052%40%21%4020140704190856%5F1610362%40%21%40JAVA%E8%B3%87%E6%B7%B1%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E5%B8%AB%24%21%2420110520143447%5F80472760%40%21%4020171026144907%5F38837863%40%21%40JAVA%E7%A8%8B%E5%BC%8F%E8%A8%AD%E8%A8%88%E5%B8%AB; ASPSESSIONIDQQACCRSA=GABBAALCHHPFFHJDHBBKCOND; ASP.NET_SessionId=721424589; StepCookie_id=721424589; step=19; ASPSESSIONIDAABRSTRT=IBAPCAACKJCAJONDPACBOHCB; citrix_ns_id=yXslN8/u40/byvXXfovfuGPjMC8A000",
    "Host": "www.yes123.com.tw",
    "Origin": "https://www.yes123.com.tw",
    "Pragma": "no-cache",
    "Referer": "https://www.yes123.com.tw/admin/job_refer_list.asp",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"
}''')

datas = []

for strrec in range(20,101,20):
    print("strrec %s has input"%strrec)
    resp = requests.post(url, data=data, headers=headers)
    resp.encoding = 'utf-8'
    data['strrec'] = strrec
    job_html = resp.text
    soup = BeautifulSoup(job_html, 'lxml')
    for no in range(0,20):
        row = {}
        try:
            row['date'] = soup.select('li.date2')[int('{0}'.format(no+1))].string
        except IndexError:
            break
        row['JobTitle'] = soup.select('span.t0 > a')[int('{0}'.format(no))]['title']
        row['company'] = soup.select('span.t1 > a')[int('{0}'.format(no))]['title']
        try:
            row['salary'] = soup.select('div.t2_1_2')[int('{0}'.format(no))].string
        except IndexError:
            row['salary'] = '未填寫'
        row['description'] = soup.select('span.t3')[int('{0}'.format(no))].string  
        datas.append(row)
# Out:
# strrec 20 has input
# strrec 40 has input
# strrec 60 has input
# strrec 80 has input
# strrec 100 has input

# %%
datas
# Out:
# [{'JobTitle': 'D4000 網站開發工程師(Java)',
#   'company': '富邦媒體科技股份有限公司',
#   'date': '01.24',
#   'description': '1.Java 網站程式開發與維護。\r\n2.電子商務網站系統分析與規劃。',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'D4000 大數據平台工程師(Java)',
#   'company': '富邦媒體科技股份有限公司',
#   'date': '01.24',
#   'description': '1.JAVA大數據平台開發和維運。\n2.大數據開源(open source)方案研究。\n3.主管交辦其他任務。',
#   'salary': '待遇面議'},
#  {'JobTitle': 'D4000 MIS程式開發工程師(JAVA)',
#   'company': '富邦媒體科技股份有限公司',
#   'date': '01.24',
#   'description': '1.電子表單系統JAVA程式開發與系統維護。\n2.協助表單系統分析、規劃、測試及流程改善優化。',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'D4000 網站開發工程師(Java)-台中',
#   'company': '富邦媒體科技股份有限公司',
#   'date': '01.24',
#   'description': '1.Java 網站程式開發與維護。\n2.電子商務網站系統分析與規劃。',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'D4000 系統開發架構師(JAVA)',
#   'company': '富邦媒體科技股份有限公司',
#   'date': '01.24',
#   'description': '1.Java 系統架構規劃。\n2.Java 新技術之研究。\n3.Java Web Applicaton、API 架構制定。\n4.對工程師開發之程式進行 code review。',
#   'salary': '待遇面議'},
#  {'JobTitle': 'JAVA程式設計師',
#   'company': '捕夢網數位科技有限公司',
#   'date': '01.23',
#   'description': '1.Java軟體平台開發 \n2.熟悉Java SE/Java EE 程式設計與開發 \n3.熟悉Spring/Jquery/JavaScript/Ajax/JSON開發應用 \n4.熟悉資料庫SQL server/Oracle開發應用 \n5.良好的理解、表達能力...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'JAVA資深程式設計師',
#   'company': '遠雄人壽保險事業股份有限公司',
#   'date': '01.23',
#   'description': '1.負責Java應用系統開發及維護。\n2.負責各項專案開發及執行。\n',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'Java軟體工程師(LT)',
#   'company': '(PChome)網路家庭國際資訊股份有限公司',
#   'date': '01.23',
#   'description': 'Java程式開發',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'Java工程師(B0203)',
#   'company': '(PChome)網路家庭國際資訊股份有限公司',
#   'date': '01.23',
#   'description': '程式撰寫Java',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'JAVA工程師 (支付服務)(E0804)',
#   'company': '(PChome)網路家庭國際資訊股份有限公司',
#   'date': '01.23',
#   'description': '程式開發與維護',
#   'salary': '待遇面議'},
#  {'JobTitle': '資訊-Java程式設計師',
#   'company': '(台新金控)台新國際商業銀行股份有限公司',
#   'date': '01.23',
#   'description': '工作內容：\r\r\n1.偕同廠商與使用者進行需求訪談\r\r\n2.境外高資產客戶平台建置維運作業\r\r\n\r\r\n資格條件：\r\r\n1.大學以上畢業\r\r\n2.熟悉JAVA、Spring、Hibernate、Eclipse、AJAX(Javascript / ...',
#   'salary': '待遇面議'},
#  {'JobTitle': '資訊-Java資深程式設計師(影像系統)',
#   'company': '(台新金控)台新國際商業銀行股份有限公司',
#   'date': '01.23',
#   'description': None,
#   'salary': '待遇面議'},
#  {'JobTitle': '資訊-Java程式設計師(網銀/電子支付)',
#   'company': '(台新金控)台新國際商業銀行股份有限公司',
#   'date': '01.23',
#   'description': '1.網路銀行、電子支付平台需求訪談及交易程式開發\r\r\n2.參與需求訪談，進行系統分析/設計/開發/測試及維護\r\r\n\r\r\n資格條件：\r\r\n1.熟 JAVA, JSP, \r\r\n2.熟HTML, JavaScript, JQuery,Jas...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'Java工程師',
#   'company': '萬海航運股份有限公司',
#   'date': '01.22',
#   'description': '1. 負責Java/app程式設計、編碼、測試、實施及維護\n2. 網站相關產品及資料維護',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '工程類(台北)-Java IOT工程師',
#   'company': '可成科技股份有限公司',
#   'date': '01.22',
#   'description': '1. Raspberry Pi on Android Things or ubuntu。\r\n2. TCP/UDP Socket or RS232。\r\n3. Bluetooth LE。',
#   'salary': '待遇面議'},
#  {'JobTitle': '資深Java/J2EE程式設計師 (台北)【BU68-電信整合資訊技術開發處】',
#   'company': '敦陽科技股份有限公司',
#   'date': '01.22',
#   'description': '大型電子商務平台/Portal平台/O2O平台/Big Data平台專案系統程式開發:\r\n\r\n工作條件:\r\n\r\n1. 熟悉JSP/Servlet/JDBC/XML/Web Service\r\n\r\n2. 使用過任何一種Application Server: WebLogic...',
#   'salary': '待遇面議'},
#  {'JobTitle': '約聘 軟體工程師 (Java or C#) (新竹)【BU2-BTB】【敦陽資訊】',
#   'company': '敦陽科技股份有限公司',
#   'date': '01.22',
#   'description': '工作內容：\r\r\n1. 負責軟體程式撰寫（前、後端）。\r\r\n2. 進行軟體之測試與修改。\r\r\n專長：\r\r\n-  JSP/Servlet, Java , C# 。\r\r\n\r\r\n其他:\r\r\n- 協助部門的專案開發及維運。\r\r\n- 使用MVC架構...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'JavaScript/JQuery 程式互動設計師(B0202)',
#   'company': '(PChome)網路家庭國際資訊股份有限公司',
#   'date': '01.23',
#   'description': '網頁製作設計',
#   'salary': '待遇面議'},
#  {'JobTitle': 'C3811 電子錢包 Java(資深)開發工程師',
#   'company': '遠傳電信股份有限公司',
#   'date': '01.18',
#   'description': '主要負責friDAY電子錢包系統相關事宜:\r\n\r\n1.配合加值服務產品的上線計劃，支援開發工作與維護服務中的應用程式\r\n2.系統設計、開發及維護\r\n3.進行軟體之測試與修改',
#   'salary': '待遇面議'},
#  {'JobTitle': 'I3101 應收管理系統工程師 (板橋,熟Java)',
#   'company': '遠傳電信股份有限公司',
#   'date': '01.18',
#   'description': '此職位主要負責帳務系統相關領域之工作, 其工作內容如下:\r\n\r\n1.使用者需求收集及分析\r\n2.系統分析及設計\r\n3.程式開發支援及測試\r\n4.協調使用者測試\r\n5.相關日常維運及問題處理\r\n6.專案支...',
#   'salary': '未填寫'},
#  {'JobTitle': 'C3811 Java開發 工程師(內湖)_電子金流平台',
#   'company': '遠傳電信股份有限公司',
#   'date': '01.18',
#   'description': '負責加值服務平台軟體之分析、設計以及程式開發,工作內容為:\r\n\r\n- 平台上線前測試\r\n- 平台日常維運\r\n- 主管交辦事項',
#   'salary': '待遇面議'},
#  {'JobTitle': 'C3811 Java開發 (資深)工程師(內湖)_電子金流平台',
#   'company': '遠傳電信股份有限公司',
#   'date': '01.18',
#   'description': 'To be a task force leader and executor within payment platform system related scope.  He/she needs to provide payment future road map including transition plan, hardware architecture, new technology and othe...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'C3111 Java開發 資深工程師',
#   'company': '遠傳電信股份有限公司',
#   'date': '01.18',
#   'description': '(1)Java 開發工程師 \r\n(2)具備 Internet OTT 服務 or 影音服務平台開發/運營經驗',
#   'salary': '待遇面議'},
#  {'JobTitle': 'C3811 Java開發 技術副理(內湖)',
#   'company': '遠傳電信股份有限公司',
#   'date': '01.18',
#   'description': 'A technical assistant manager to lead the team to develop and maintain the platforms & services, mainly focus on mobile and Internet payment services, is responsible for the followings:\r\n1. Lead and ass...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'R-Java SD/PG',
#   'company': '緯創軟體股份有限公司',
#   'date': '01.15',
#   'description': '1. 負責金融/電信/製造業/IT/電子等專案系統之分析、設計以及程式撰寫。\r\n2. 規劃執行軟體架構及模組之設計，並控管軟體設計進度。\r\n3. 進行軟體之測試與修改。\r\n4. 規劃、執行與維護...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'R-Java Full Stack Dev Lead',
#   'company': '緯創軟體股份有限公司',
#   'date': '01.15',
#   'description': 'WistronITS is  looking  for  intelligent,  creative,  and  dedicated Java Full Stack \r\r\nLead  to  join  our  Engineering team. The lead will be responsible for managing \r\r\nand expanding the team, arc...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'JAVA系統設計師',
#   'company': '女子徵信有限公司',
#   'date': '01.02',
#   'description': '1.製程改善，良率提升，製程監控，專案執行\n2.與客戶或公司的硬體部門的同仁共同研發或解決問題\n3.擬定專案範疇符合成本、品質、規格，並將工作分配給專案成員\n4.協助軟體設計及問題...',
#   'salary': '待遇面議'},
#  {'JobTitle': '程式設計工程師',
#   'company': '旭德科技股份有限公司',
#   'date': '01.24',
#   'description': '1. 軟體設計與程式撰寫。\r\r\n2. 負責 Webform、Winform、APP 程式開發。\r\r\n3. 熟悉 C#, Delphi, VB , .Net, Java 等程式語言。\r\r\n4. 熟悉 Oracle 、 MS-SQL 等 SQL 。\r\r\n5. 具異質系統...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '☄ PHP程式設計師 ☄',
#   'company': '中美國際教育有限公司',
#   'date': '01.24',
#   'description': '1.管理伺服器,基本網路及電腦問題處理。 \n2.熟悉 PHP 程式設計、JQuery 及 MS SQL資料庫。 \n3.熟悉 JavaScript、CSS及DHTML等程式設計尤佳。 \n4.開發/設計/維護 PHP 網站 及...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '資訊管理類-MIS儲備幹部(深圳廠或崑山廠)',
#   'company': '凌巨科技股份有限公司',
#   'date': '01.24',
#   'description': '1.負責開發.NET、Java、Oracle DB 任一相關軟體。 \n2.儲備主管',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'D4000 資深網站開發工程師',
#   'company': '富邦媒體科技股份有限公司',
#   'date': '01.24',
#   'description': '1.Java 網站程式開發與維護。\r\n2.電子商務網站系統分析與規劃。',
#   'salary': '待遇面議'},
#  {'JobTitle': '互聯網+智能軟體優秀研發人才(台北/台中)年前卡位，年後SAY YES!',
#   'company': '鼎新電腦股份有限公司',
#   'date': '01.24',
#   'description': '▶攜手打造亞洲矽谷，建構 開放 共享 的智能新局◀\r\n▶運用輕量化虛擬技術打造私有雲平台◀\r\n\r\n☛主動積極，勇於創新、挑戰新事物！\r\n☛樂於分析思考，快速解決問題！\r\n☛重視用戶體...',
#   'salary': '待遇面議'},
#  {'JobTitle': '軟體工程師',
#   'company': '青松健康事業-青松護理之家',
#   'date': '01.24',
#   'description': None,
#   'salary': '待遇面議'},
#  {'JobTitle': 'PHP程式設計師',
#   'company': '捕夢網數位科技有限公司',
#   'date': '01.23',
#   'description': '1.使用PHP+Mysql開發網頁應用程式。 \n2.熟悉 PHP + MySQL。 \n3.熟悉 JavaScript。 \n4.需有物件導向觀念。 \n5.熟悉 HTML,CSS 語法。 \n6.熟悉 Linux者佳。 \n7.善於溝通、表達能力...',
#   'salary': '待遇面議'},
#  {'JobTitle': '助理工程師(需輪大夜班)',
#   'company': '捕夢網數位科技有限公司',
#   'date': '01.23',
#   'description': '職務說明:\n1.具備資料庫網頁程式撰寫經驗佳.\n2.熟悉作業系統，Linux 與Windows 管理與維護。\n3.具備網路伺服器(Web、FTP、DNS、Mail)實務架設經驗者佳.\n4.具備程式撰寫能力者佳(PH...',
#   'salary': '待遇面議'},
#  {'JobTitle': '(中和) Android智慧型手機 Framework/APP (軟體) 資深/高級工程師/工程師',
#   'company': '華冠通訊股份有限公司',
#   'date': '01.23',
#   'description': '1. Android phone AP / Framework layer development / integration / debugging\r\r\n2. Customer / Operator SW feature implementation\r\r\n3. C/C++/Java software programming\r\r\n4. 2 years+ experience (nice to ...',
#   'salary': '待遇面議'},
#  {'JobTitle': '尖端所-雲端平台工程師(台中)',
#   'company': '宏遠興業股份有限公司',
#   'date': '01.23',
#   'description': '工作單位：智慧穿載電子部門\r\n開發方式: Dreamweaver CS6  等不限\r\n開發項目：雲端管理平台，網站平台，Database存取介面\r\n職務需求：\r\n1. 精通Java語言和物件導向設計方法，熟練掌握J...',
#   'salary': '未填寫'},
#  {'JobTitle': '尖端所-APP工程師(台中)',
#   'company': '宏遠興業股份有限公司',
#   'date': '01.23',
#   'description': None,
#   'salary': '未填寫'},
#  {'JobTitle': '潤泰Fashion Cookie & Corpo網站程式設計師',
#   'company': '潤泰全球股份有限公司',
#   'date': '01.23',
#   'description': '1.扎實的 HTML、JavaScript、CSS 知識與技能。\r\n2.Ruby on Rails 網站開發經驗或可學習Ruby on Rails相關技術，\r\n使用過其他 web framework，了解 MVC 架構、習慣物件導向程式設計\r\n3...',
#   'salary': '未填寫'},
#  {'JobTitle': '[Server]系統軟體工程師(桃園)',
#   'company': '英業達股份有限公司',
#   'date': '01.23',
#   'description': '負責產品以及系統之後端程式開發\r\n熟悉Java / RESTful架構者尤佳\r\n有相關經驗者尤佳',
#   'salary': '未填寫'},
#  {'JobTitle': '[Server]MES 系統開發工程師(上海)',
#   'company': '英業達股份有限公司',
#   'date': '01.23',
#   'description': '1.開發MES 測試、組裝及配銷生產管理系統軟體 \r\n2.開發收集機台生產資料平台及生產資訊分析管理報表\r\n3.收集生產管理需求\r\n4.具備 C#、ASP.NET、Javascript、JQuery、SQL語言 ...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '資訊-法金授信系統程式設計師',
#   'company': '(台新金控)台新國際商業銀行股份有限公司',
#   'date': '01.23',
#   'description': '工作內容：法金授信系統開發及維運\r\r\n資格條件：\r\r\n1. 熟悉  Java ,JSP,HTML及SQL語法 \r\r\n2. 具備良好的問題分析解決能力、責任心強、具獨立作業及團隊合作能力',
#   'salary': '待遇面議'},
#  {'JobTitle': 'HTML 5 Programmer',
#   'company': '益升科技有限公司',
#   'date': '01.23',
#   'description': '1. HTML切片和轉換PSD（photoshop圖像）到HTML\n2. 需會HTML 5與CSS 3 \n3. 必須會JQuery 和 Java Script\n4. 能使用PHP優\n5. 另有大夜津貼\n6. 英文程度中等以上',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'CIM資訊整合工程師(桃園廠)',
#   'company': '世界先進積體電路股份有限公司',
#   'date': '01.23',
#   'description': '1.FAB 支援生產應用系統開發與維護 2.FAB 資訊相關應用報表開發與維護3.FAB 生產規劃系統開發與維護工作條件：1.大學以上學歷(含)，資訊相關科系所畢，對半導體生產流程有興趣者...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'CIM自動化工程師(新竹廠)',
#   'company': '世界先進積體電路股份有限公司',
#   'date': '01.23',
#   'description': '1.大學以上，資訊工程、機械、電機等相關系所畢2.熟悉Visual Basic, C/C++, Java, SQL, Oracle, Unix, Windows3.具半導體或TFT-LCD廠機台連線,Oracle 程式開發或分散式系統開發經驗...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'GUI人機介面設計工程師(新竹)',
#   'company': '建漢科技股份有限公司',
#   'date': '01.22',
#   'description': '1. 負責Mobile Device [Cell phone, Pad, Tablet...]應用程式的介面流程規劃及設計\r\r\n2. 工作內容:\r\r\n - Familiar with HTML5, HTML, JavaScript, ActionScript 2.0/3.0\r\r\n - 3D drawing, Phot...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '工程類(台北)-程式開發工程師',
#   'company': '可成科技股份有限公司',
#   'date': '01.22',
#   'description': '1.熟悉 W3C HTML及相關DHTML技術/CSS語法/DOM模型。\r\n2.熟悉 JavaScript語言。\r\n3.熟悉 ASP.NET VB或C#語言。',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '工程類-Web 前端工程師',
#   'company': '可成科技股份有限公司',
#   'date': '01.22',
#   'description': '1. 熟悉 HTML/CSS/DOM。 \r\n2. 熟悉Javascript/jQuery/AngularJS/Cordova。\r\n3. 熟悉Agile/DevOps CI CD/Git。',
#   'salary': '待遇面議'},
#  {'JobTitle': 'TC_軟體工程師(技術中心)',
#   'company': '遠通電收股份有限公司',
#   'date': '01.22',
#   'description': '1.因應系統或專案需求進行Java或 .Net 軟體開發及測試\r\r\n2.系統異常分析與處理\r\r\n3.因應需求進行系統調整或精進',
#   'salary': '待遇面議'},
#  {'JobTitle': 'IAS_軟體工程師',
#   'company': '遠通電收股份有限公司',
#   'date': '01.22',
#   'description': '資訊系統開發及介面整合:\r\r\n1.與使用者訪談需求並進行系統及流程設計。\r\r\n2.平日執行資訊系統的日常維運作業。\r\r\n3.進行ETC系統資料分析以作為未來系統調整以及加值服務應用。\r\r\n4.車...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'S.電子商務‧ASP .NET 系統分析師',
#   'company': '永豐餘消費品實業股份有限公司',
#   'date': '01.22',
#   'description': '1.熟悉C#.NET (.NET Framework 2.0以上)。\n2.具有MVC架構、物件導向設計實務專案經驗尤佳。\n3.具 LINQ / Entity Framework 開發經驗尤佳。\n4.熟悉Web(JavaScript、jQuery、Ajax)應...',
#   'salary': '待遇面議'},
#  {'JobTitle': '資深大數據平台開發工程師(台北)【BU68(IQ)-電信EC】',
#   'company': '敦陽科技股份有限公司',
#   'date': '01.22',
#   'description': '1.Hadoop-based應用系統安裝、設定與維護。\r\r\n2.具備2年以上Python + Spark程式設計實務經驗。\r\r\n3.具備Kafka, Hue, Pentaho ETL Tool相關經驗尤佳。\r\r\n4.具備Java基本觀念尤佳。\r\r\n5.樂於...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '資訊工程師(網頁開發),無經驗可',
#   'company': '燿華電子股份有限公司',
#   'date': '01.22',
#   'description': '1. Java, Jsp開發作業與維護。 \r\n2. 企業流程系統開發作業與維護。 \r\n3. 企業入口建置與維護。',
#   'salary': '待遇面議'},
#  {'JobTitle': '軟體設計工程師',
#   'company': '敦陽科技股份有限公司',
#   'date': '01.22',
#   'description': '1. 熟悉JSP/Servlet/JDBC/XML/Web Service\r\n2. 使用過任何一種Application Server: WebLogic,JBOSS\r\n3. 網頁技術：HTML,Java Script,AJAX\r\n4. Spring ,Struts,Hibernate等技術框...',
#   'salary': '待遇面議'},
#  {'JobTitle': '大數據平台開發工程師(台北)【BU68(IQ)-電信EC】',
#   'company': '敦陽科技股份有限公司',
#   'date': '01.22',
#   'description': '電信大數據平台程式開發\r\r\n1. 具備Python + Spark程式設計實務經驗。\r\r\n2. 具備Kafka, Hue, Pentaho ETL Tool相關經驗尤佳。 \r\r\n3. 具備Java基本觀念尤佳。 \r\r\n4. 樂於團隊合作、具備良好...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'J2EE 系統設計師 【BU68 電信整合資訊技術開發處】',
#   'company': '敦陽科技股份有限公司',
#   'date': '01.22',
#   'description': '大型電子商務平台/Portal平台/O2O平台/Big Data平台專案系統程式開發:\r\n\r\n工作條件:\r\n\r\n1. 熟悉JSP/Servlet/JDBC/XML/Web Service\r\n\r\n2. 使用過任何一種Application Server: WebLogic...',
#   'salary': '待遇面議'},
#  {'JobTitle': '【松山區】(前期海外受訓)駐點軟體工程師(應屆畢業生可)-21',
#   'company': '汎亞國際人事顧問股份有限公司',
#   'date': '01.22',
#   'description': '工作內容：\n1.負責程式設計、修改、測試及上線。  \n2.負責規劃並執行後台(BackOffice)軟體系統之上線及維護。  \n3.各類技術文件及報告之撰寫。  \n前三個月海外受訓地點：上海\n(來回機票...',
#   'salary': '待遇面議'},
#  {'JobTitle': '尖端所-ERP Engineer(台中)',
#   'company': '宏遠興業股份有限公司',
#   'date': '01.23',
#   'description': '工作單位：智慧穿載電子部門\r\n職務類別：物流ERP-進銷存與財務Engineer\r\n開發方式：JAVA、C#、VB\r\n開發項目：PC軟體\r\n職務內容：\r\n1. 至少熟练掌握一種計算機语言，有web系統開...',
#   'salary': '待遇面議'},
#  {'JobTitle': '新產品軟體開發技術經理/副理/工程師【BU68-IM】',
#   'company': '敦陽科技股份有限公司',
#   'date': '01.22',
#   'description': '職務說明：\r\n1.熟Java MVC架構\r\n2.具網站開發經驗\r\n3.應徵技術資深經理需有帶人經驗至少五人以上.',
#   'salary': '未填寫'},
#  {'JobTitle': '資訊部儲備主管',
#   'company': '童綜合醫療社團法人童綜合醫院',
#   'date': '01.19',
#   'description': None,
#   'salary': '未填寫'},
#  {'JobTitle': '資訊部儲備幹部',
#   'company': '童綜合醫療社團法人童綜合醫院',
#   'date': '01.19',
#   'description': None,
#   'salary': '待遇面議'},
#  {'JobTitle': 'JSP網頁程式設計師',
#   'company': '力天資訊科技股份有限公司',
#   'date': '01.19',
#   'description': None,
#   'salary': '待遇面議'},
#  {'JobTitle': 'Android軟體工程師I',
#   'company': '矽華軟體有限公司',
#   'date': '01.19',
#   'description': '1. 理工科系畢, 軟體程式開發2年以上相關經驗. \n2. MUST HAVE: Java and C++ programming on Android development environment. \n3. OPTIONAL: SQL, C#, Lua, Python, ASP .Net 或自...',
#   'salary': '待遇面議'},
#  {'JobTitle': '資訊儲備幹部(一)',
#   'company': '臺南紡織股份有限公司',
#   'date': '01.19',
#   'description': '1.大學以上資訊相關系所畢\r\r\n2.MIS系統分析、設計與維護\r\r\n3.AS400系統管理\r\r\n4.AS400/CLP、AS400/RPG、Delphi、JAVA、Jcva Script\r\r\n5.DB/400，MS SQL\r\r\n6.Windows各版本\r\r\n7...',
#   'salary': '待遇面議'},
#  {'JobTitle': '網頁視覺設計師(台北)',
#   'company': '國眾電腦股份有限公司',
#   'date': '01.19',
#   'description': '1.   主要工作項目為網頁程式開發\r\n熟悉以下語法：PHP、MySQL、Java Script，熟悉運用CSS3、HTML5、jQuery等 Web 技術製作網頁。\r\n2. 可以具抗壓性，且能獨立作業。\r\n3. 對程式...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '自動控制工程師(高雄)',
#   'company': '國眾電腦股份有限公司',
#   'date': '01.19',
#   'description': '1.自控系統專案規劃、執行\r\n2.DDC軟體,圖控軟體程式撰寫\r\n3.JAVA,網頁程式選寫\r\n4.PLC軟體選寫\r\n5.協助業務進行自動化控制系統設計.規劃及估價\r\n6.協助業務作案件開發及客戶情感...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '軟體開發工程師(內湖)',
#   'company': '國眾電腦股份有限公司',
#   'date': '01.19',
#   'description': '1. .NET、Java程式撰寫\r\n2. Web開發作業\r\n3. 資料庫應用\r\n4. 金融軟體開發',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '軟體工程師',
#   'company': '甘霖有限公司',
#   'date': '01.18',
#   'description': '1.負責開發工作流程(BPM or WorkFlow)專案。\n2.熟JavaScript、Java, JSP, SQL 程式撰寫。\n3.負責軟體之分析、設計以及程式撰寫。\n4.無經驗但對軟體開發有高度熱忱者亦可。',
#   'salary': '待遇面議'},
#  {'JobTitle': '程式設計師(有無經驗皆可)',
#   'company': '甘霖有限公司',
#   'date': '01.18',
#   'description': '有JAVA經驗，懂RAD、JSF，WAS，Hibernate等，歡迎具團隊精神，肯學習，負責任，願意投入軟體產業的有志之士，能接受挑戰者，與本公司聯絡。',
#   'salary': '待遇面議'},
#  {'JobTitle': '【松山區】(前期海外培訓)駐點軟體工程師(應屆畢業生可)-21',
#   'company': '汎亞國際人事顧問股份有限公司',
#   'date': '01.18',
#   'description': '工作內容：\n1.負責程式設計、修改、測試及上線。  \n2.負責規劃並執行後台(BackOffice)軟體系統之上線及維護。  \n3.各類技術文件及報告之撰寫。  \n前三個月海外受訓地點：上海\n(來回機票...',
#   'salary': '待遇面議'},
#  {'JobTitle': '軟體顧問師',
#   'company': '(GD-CRM)通用數碼股份有限公司',
#   'date': '01.18',
#   'description': '1). 協助客戶進行GD-CRM系統導入之專案規劃、進度控管、上線輔導、技術移轉、個案需求分析與設計。\n(2). 協助客戶解決GD-CRM系統運作所遭遇之各種操作及應用問題。\n\n需具備之經...',
#   'salary': '待遇面議'},
#  {'JobTitle': '軟體服務工程師',
#   'company': '(GD-CRM)通用數碼股份有限公司',
#   'date': '01.18',
#   'description': '(1). 系統問題排除。\n(2). 系統版本更新維護。\n(3). 客製化程式撰寫與維護。 \n(4). 系統安裝。\n\n需具備：\n(1)基本專業技能需求：HTML、SQL Server、Java Script、C#.Net\n(2)具備網頁程...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '程式設計師',
#   'company': '莫絲皮件護理棧',
#   'date': '01.18',
#   'description': '1.資料庫系統設計、管理、維護能力\n2.軟體工程的開發、設計、整合測試\n3.熟悉並撰寫網頁語法 \n4.網路程式設計\n電腦技能：程式設計：PHP\n資料庫：MySQL\n網頁技術：HTML／Java Sc...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'Linux kernel/device driver development Engineer/主管 - J0394',
#   'company': '廣達電腦股份有限公司',
#   'date': '01.18',
#   'description': None,
#   'salary': '待遇面議'},
#  {'JobTitle': '自動化程式開發主管/專員 - J0168',
#   'company': '廣達電腦股份有限公司',
#   'date': '01.18',
#   'description': '1. Server/Storage/Networking Validation automation development by Java, Python, Linux Bash or Windows Powershell\r\r\n2. System analysis on validation automation requirements and project/ schedule deve...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': '應用軟體工程師-(工作地點:台北市民生科技大樓)',
#   'company': '康舒科技股份有限公司',
#   'date': '01.18',
#   'description': '康舒科技的前瞻技術研究中心現在在尋找資訊工程或相關科系的軟體開發人才。你將會開發智慧電表的後台系統。\n\n我們希望應徵者能具有下列特性:\n●具有團隊精神\n●解決問題的邏輯思考\n...',
#   'salary': '待遇面議'},
#  {'JobTitle': '網頁設計管理人員',
#   'company': '九九行國際有限公司',
#   'date': '01.19',
#   'description': '1..熟悉電腦修圖與影像合成。\n2..擅長網頁設計、平面廣告設計經驗(請務必附作品參考) 。\n具網頁設計相關經驗，HTML、CSS/DIV切版，JavaScript、jQuery，熟悉語言架構，解決各種...',
#   'salary': '待遇依公司規定'},
#  {'JobTitle': 'Android應用工程師(內湖)－71101',
#   'company': '精技電腦股份有限公司',
#   'date': '01.17',
#   'description': '[工作內容]\n1.負青開發應用企業營運之Android APP\n2.研究新技術與新工具，公司亦會主動規畫參與研討會及教育訓練\n\n \n[ 專長與特質 ]\n1. 熟悉Java、Android SDK、框架運作原理、SQLi...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'PHP 程式設計師─71101',
#   'company': '精技電腦股份有限公司',
#   'date': '01.17',
#   'description': '[工作內容]\n負責PHP 網頁應用程式之開發與維護\n\n[技能]\n1.有學習過PHP網頁語言、資料庫及 SQL 語法、HTML及CSS 語法\n2.有JavaScript 應用經驗更佳',
#   'salary': '未填寫'},
#  {'JobTitle': 'php網路程式設計師',
#   'company': '欣揚科技有限公司',
#   'date': '01.17',
#   'description': '1. 熟悉 PHP 程式語言。\n2. 熟悉 MySQL 資料庫。\n3. 瞭解 HTML 、 Java Script 、 CSS 、 jQuery 等Web技術。\n4. 重視team work',
#   'salary': '未填寫'},
#  {'JobTitle': '軟體維護工程師',
#   'company': '甘霖有限公司',
#   'date': '01.18',
#   'description': '1.維護公司現有各項產品與服務之相關軟體(JAVA Base)\n2.不需業務開發、不需有豐富經驗，本公司會培訓\n3.客戶多，主要處理企業軟體使用相關問題(可連結網頁)\n企業網址 ： http://www.as...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'ASP.NET MVC軟體工程師',
#   'company': '一訂科技股份有限公司',
#   'date': '01.16',
#   'description': '所需技術\n前端：HTML5 + CSS3 + Bootstrap + Java Script + jQuery +  (AJAX) + AngularJS\n後端：MVC + WEB API + Entity Framework + MS SQL 2008 以上\n版控：Microsoft Team S...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'PHP網頁後端工程師',
#   'company': '富比庫股份有限公司',
#   'date': '01.16',
#   'description': '1.後端網頁設計開發與維護\n2.熟悉PHP、MySQL、Javascript、等Web開發能力。\n3.了解關聯式資料庫的概念。\n4.使用Framework 共同開發',
#   'salary': '待遇面議'},
#  {'JobTitle': '網路程式設計師',
#   'company': '(大當家聯合網)成商數位整合有限公司',
#   'date': '01.16',
#   'description': '帶著您的網頁設計創意來吧!!\n我們重視團隊合作的觀念並堅持以使用者體驗為優先考量，\n如果你想要有個一展長才的機會，\n能夠成為網頁程式設計的佼佼者，\n那就不要錯過機會，快來加入...',
#   'salary': '待遇面議'},
#  {'JobTitle': '行動裝置APP程式設計師',
#   'company': '展輝科技股份有限公司',
#   'date': '01.16',
#   'description': '1.Android/IOS APP開發\n2.程式語言：HTML/CSS/JavaScript/Jquery(有C#基礎及熟悉ASP.NET MVC開發者佳)\n3.開發工具：Visual Studio Apache Cordova /MS SQL\n4.善於溝通表達...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'Internet程式設計師',
#   'company': '展輝科技股份有限公司',
#   'date': '01.16',
#   'description': '1.資訊管理系統與網站開發(有RWD基礎者佳)\n2.程式語言：C#/ASP.NET MVC/JavaScript/Jquery\n3.開發工具：Visual Studio/MS SQL\n4.善於溝通表達與團隊合作，歡迎主動積極的你一...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'HK-軟體工程師(工作地：香港)',
#   'company': '緯創軟體股份有限公司',
#   'date': '01.15',
#   'description': '1. 至香港客戶端環境開發工作。\r\r\n2. 手機/平板平台語音互動軟體開發。\r\r\n3. 所需條件\r\r\n    ●Know Java, and/or a major programming language; \r\r\n    ●Comfortable with Terminal/bash \r\r\n    ●B...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'R-Front-End Developer',
#   'company': '緯創軟體股份有限公司',
#   'date': '01.15',
#   'description': '1. Write clean, modern JavaScript code to create fantastic and user-friendly \r\r\n     experiences \r\r\n2. You will be using modern frameworks and technologies such as Angular.js or Electron and more to crea...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'R-前端工程師 (AngularJS)',
#   'company': '緯創軟體股份有限公司',
#   'date': '01.15',
#   'description': '1.Responsible for design, coding, unittesting, review and implementation \r\r\n   application and services by using Java Enterprise Application framework \r\r\n   such as Spring, Hibernate, JPA, Spring Bo...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'R-大數據資料分析師',
#   'company': '緯創軟體股份有限公司',
#   'date': '01.15',
#   'description': '1. 因應客戶對大數據之需求進行開發，操作、監測ETL數據。\r\r\n2. 使用ETL進行蒐集、清洗。\r\r\n3. 使用SSIS…等工具處理資料，並以Hadoop…等工具儲存並支援數據分析任務。\r\r\n4. 依...',
#   'salary': '待遇面議'},
#  {'JobTitle': 'R-MES (Location : Taipei)',
#   'company': '緯創軟體股份有限公司',
#   'date': '01.15',
#   'description': '1.Be able to travel or on-site Taichung, Tainan,China flexiblly  \r\n2.Fmailiar with Java, C#, VB.NET (at lease 2 yrs) \r\n3.Bachelor degree or above in CE/CS/CIS releated major \r\n4.Be willing...',
#   'salary': '待遇面議'},
#  {'JobTitle': '軟體工程師',
#   'company': '子辰國際開發股份有限公司',
#   'date': '01.15',
#   'description': '1. 具備 Java、HTML、CSS、Javascript 網頁技術相關經驗\n2. 孰悉MySQL語法\n3. 樂於溝通與積極學習\n',
#   'salary': '未填寫'},
#  {'JobTitle': '竹南02H_資訊-(助理)工程師',
#   'company': '微矽電子股份有限公司',
#   'date': '01.11',
#   'description': '1、JAVA程式開發。\n2、維護公司網路系統。\n3、其它交辦事項',
#   'salary': '未填寫'},
#  {'JobTitle': '網路平台開發RD工程師',
#   'company': '沛盛資訊有限公司',
#   'date': '01.05',
#   'description': '喜愛研發設計，熟ASP‧Net程式設計，熟C#或VB.Net等語言，有網站程式設計經驗者，對AI、大數據分析有興趣，對設計軟體雲端產品設計有熱誠及熟 JavaScript/CSS3、 RWD、資料...',
#   'salary': '未填寫'}]

# %%
for row in datas:
    print(row)
# Out:
# {'date': '01.24', 'JobTitle': 'D4000 網站開發工程師(Java)', 'company': '富邦媒體科技股份有限公司', 'salary': '待遇依公司規定', 'description': '1.Java 網站程式開發與維護。\r\n2.電子商務網站系統分析與規劃。'}
# {'date': '01.24', 'JobTitle': 'D4000 大數據平台工程師(Java)', 'company': '富邦媒體科技股份有限公司', 'salary': '待遇面議', 'description': '1.JAVA大數據平台開發和維運。\n2.大數據開源(open source)方案研究。\n3.主管交辦其他任務。'}
# {'date': '01.24', 'JobTitle': 'D4000 MIS程式開發工程師(JAVA)', 'company': '富邦媒體科技股份有限公司', 'salary': '待遇依公司規定', 'description': '1.電子表單系統JAVA程式開發與系統維護。\n2.協助表單系統分析、規劃、測試及流程改善優化。'}
# {'date': '01.24', 'JobTitle': 'D4000 網站開發工程師(Java)-台中', 'company': '富邦媒體科技股份有限公司', 'salary': '待遇依公司規定', 'description': '1.Java 網站程式開發與維護。\n2.電子商務網站系統分析與規劃。'}
# {'date': '01.24', 'JobTitle': 'D4000 系統開發架構師(JAVA)', 'company': '富邦媒體科技股份有限公司', 'salary': '待遇面議', 'description': '1.Java 系統架構規劃。\n2.Java 新技術之研究。\n3.Java Web Applicaton、API 架構制定。\n4.對工程師開發之程式進行 code review。'}
# {'date': '01.23', 'JobTitle': 'JAVA程式設計師', 'company': '捕夢網數位科技有限公司', 'salary': '待遇依公司規定', 'description': '1.Java軟體平台開發 \n2.熟悉Java SE/Java EE 程式設計與開發 \n3.熟悉Spring/Jquery/JavaScript/Ajax/JSON開發應用 \n4.熟悉資料庫SQL server/Oracle開發應用 \n5.良好的理解、表達能力...'}
# {'date': '01.23', 'JobTitle': 'JAVA資深程式設計師', 'company': '遠雄人壽保險事業股份有限公司', 'salary': '待遇依公司規定', 'description': '1.負責Java應用系統開發及維護。\n2.負責各項專案開發及執行。\n'}
# {'date': '01.23', 'JobTitle': 'Java軟體工程師(LT)', 'company': '(PChome)網路家庭國際資訊股份有限公司', 'salary': '待遇依公司規定', 'description': 'Java程式開發'}
# {'date': '01.23', 'JobTitle': 'Java工程師(B0203)', 'company': '(PChome)網路家庭國際資訊股份有限公司', 'salary': '待遇依公司規定', 'description': '程式撰寫Java'}
# {'date': '01.23', 'JobTitle': 'JAVA工程師 (支付服務)(E0804)', 'company': '(PChome)網路家庭國際資訊股份有限公司', 'salary': '待遇面議', 'description': '程式開發與維護'}
# {'date': '01.23', 'JobTitle': '資訊-Java程式設計師', 'company': '(台新金控)台新國際商業銀行股份有限公司', 'salary': '待遇面議', 'description': '工作內容：\r\r\n1.偕同廠商與使用者進行需求訪談\r\r\n2.境外高資產客戶平台建置維運作業\r\r\n\r\r\n資格條件：\r\r\n1.大學以上畢業\r\r\n2.熟悉JAVA、Spring、Hibernate、Eclipse、AJAX(Javascript / ...'}
# {'date': '01.23', 'JobTitle': '資訊-Java資深程式設計師(影像系統)', 'company': '(台新金控)台新國際商業銀行股份有限公司', 'salary': '待遇面議', 'description': None}
# {'date': '01.23', 'JobTitle': '資訊-Java程式設計師(網銀/電子支付)', 'company': '(台新金控)台新國際商業銀行股份有限公司', 'salary': '待遇依公司規定', 'description': '1.網路銀行、電子支付平台需求訪談及交易程式開發\r\r\n2.參與需求訪談，進行系統分析/設計/開發/測試及維護\r\r\n\r\r\n資格條件：\r\r\n1.熟 JAVA, JSP, \r\r\n2.熟HTML, JavaScript, JQuery,Jas...'}
# {'date': '01.22', 'JobTitle': 'Java工程師', 'company': '萬海航運股份有限公司', 'salary': '待遇依公司規定', 'description': '1. 負責Java/app程式設計、編碼、測試、實施及維護\n2. 網站相關產品及資料維護'}
# {'date': '01.22', 'JobTitle': '工程類(台北)-Java IOT工程師', 'company': '可成科技股份有限公司', 'salary': '待遇面議', 'description': '1. Raspberry Pi on Android Things or ubuntu。\r\n2. TCP/UDP Socket or RS232。\r\n3. Bluetooth LE。'}
# {'date': '01.22', 'JobTitle': '資深Java/J2EE程式設計師 (台北)【BU68-電信整合資訊技術開發處】', 'company': '敦陽科技股份有限公司', 'salary': '待遇面議', 'description': '大型電子商務平台/Portal平台/O2O平台/Big Data平台專案系統程式開發:\r\n\r\n工作條件:\r\n\r\n1. 熟悉JSP/Servlet/JDBC/XML/Web Service\r\n\r\n2. 使用過任何一種Application Server: WebLogic...'}
# {'date': '01.22', 'JobTitle': '約聘 軟體工程師 (Java or C#) (新竹)【BU2-BTB】【敦陽資訊】', 'company': '敦陽科技股份有限公司', 'salary': '待遇依公司規定', 'description': '工作內容：\r\r\n1. 負責軟體程式撰寫（前、後端）。\r\r\n2. 進行軟體之測試與修改。\r\r\n專長：\r\r\n-  JSP/Servlet, Java , C# 。\r\r\n\r\r\n其他:\r\r\n- 協助部門的專案開發及維運。\r\r\n- 使用MVC架構...'}
# {'date': '01.23', 'JobTitle': 'JavaScript/JQuery 程式互動設計師(B0202)', 'company': '(PChome)網路家庭國際資訊股份有限公司', 'salary': '待遇面議', 'description': '網頁製作設計'}
# {'date': '01.18', 'JobTitle': 'C3811 電子錢包 Java(資深)開發工程師', 'company': '遠傳電信股份有限公司', 'salary': '待遇面議', 'description': '主要負責friDAY電子錢包系統相關事宜:\r\n\r\n1.配合加值服務產品的上線計劃，支援開發工作與維護服務中的應用程式\r\n2.系統設計、開發及維護\r\n3.進行軟體之測試與修改'}
# {'date': '01.18', 'JobTitle': 'I3101 應收管理系統工程師 (板橋,熟Java)', 'company': '遠傳電信股份有限公司', 'salary': '未填寫', 'description': '此職位主要負責帳務系統相關領域之工作, 其工作內容如下:\r\n\r\n1.使用者需求收集及分析\r\n2.系統分析及設計\r\n3.程式開發支援及測試\r\n4.協調使用者測試\r\n5.相關日常維運及問題處理\r\n6.專案支...'}
# {'date': '01.18', 'JobTitle': 'C3811 Java開發 工程師(內湖)_電子金流平台', 'company': '遠傳電信股份有限公司', 'salary': '待遇面議', 'description': '負責加值服務平台軟體之分析、設計以及程式開發,工作內容為:\r\n\r\n- 平台上線前測試\r\n- 平台日常維運\r\n- 主管交辦事項'}
# {'date': '01.18', 'JobTitle': 'C3811 Java開發 (資深)工程師(內湖)_電子金流平台', 'company': '遠傳電信股份有限公司', 'salary': '待遇面議', 'description': 'To be a task force leader and executor within payment platform system related scope.  He/she needs to provide payment future road map including transition plan, hardware architecture, new technology and othe...'}
# {'date': '01.18', 'JobTitle': 'C3111 Java開發 資深工程師', 'company': '遠傳電信股份有限公司', 'salary': '待遇面議', 'description': '(1)Java 開發工程師 \r\n(2)具備 Internet OTT 服務 or 影音服務平台開發/運營經驗'}
# {'date': '01.18', 'JobTitle': 'C3811 Java開發 技術副理(內湖)', 'company': '遠傳電信股份有限公司', 'salary': '待遇面議', 'description': 'A technical assistant manager to lead the team to develop and maintain the platforms & services, mainly focus on mobile and Internet payment services, is responsible for the followings:\r\n1. Lead and ass...'}
# {'date': '01.15', 'JobTitle': 'R-Java SD/PG', 'company': '緯創軟體股份有限公司', 'salary': '待遇面議', 'description': '1. 負責金融/電信/製造業/IT/電子等專案系統之分析、設計以及程式撰寫。\r\n2. 規劃執行軟體架構及模組之設計，並控管軟體設計進度。\r\n3. 進行軟體之測試與修改。\r\n4. 規劃、執行與維護...'}
# {'date': '01.15', 'JobTitle': 'R-Java Full Stack Dev Lead', 'company': '緯創軟體股份有限公司', 'salary': '待遇面議', 'description': 'WistronITS is  looking  for  intelligent,  creative,  and  dedicated Java Full Stack \r\r\nLead  to  join  our  Engineering team. The lead will be responsible for managing \r\r\nand expanding the team, arc...'}
# {'date': '01.02', 'JobTitle': 'JAVA系統設計師', 'company': '女子徵信有限公司', 'salary': '待遇面議', 'description': '1.製程改善，良率提升，製程監控，專案執行\n2.與客戶或公司的硬體部門的同仁共同研發或解決問題\n3.擬定專案範疇符合成本、品質、規格，並將工作分配給專案成員\n4.協助軟體設計及問題...'}
# {'date': '01.24', 'JobTitle': '程式設計工程師', 'company': '旭德科技股份有限公司', 'salary': '待遇依公司規定', 'description': '1. 軟體設計與程式撰寫。\r\r\n2. 負責 Webform、Winform、APP 程式開發。\r\r\n3. 熟悉 C#, Delphi, VB , .Net, Java 等程式語言。\r\r\n4. 熟悉 Oracle 、 MS-SQL 等 SQL 。\r\r\n5. 具異質系統...'}
# {'date': '01.24', 'JobTitle': '☄ PHP程式設計師 ☄', 'company': '中美國際教育有限公司', 'salary': '待遇依公司規定', 'description': '1.管理伺服器,基本網路及電腦問題處理。 \n2.熟悉 PHP 程式設計、JQuery 及 MS SQL資料庫。 \n3.熟悉 JavaScript、CSS及DHTML等程式設計尤佳。 \n4.開發/設計/維護 PHP 網站 及...'}
# {'date': '01.24', 'JobTitle': '資訊管理類-MIS儲備幹部(深圳廠或崑山廠)', 'company': '凌巨科技股份有限公司', 'salary': '待遇依公司規定', 'description': '1.負責開發.NET、Java、Oracle DB 任一相關軟體。 \n2.儲備主管'}
# {'date': '01.24', 'JobTitle': 'D4000 資深網站開發工程師', 'company': '富邦媒體科技股份有限公司', 'salary': '待遇面議', 'description': '1.Java 網站程式開發與維護。\r\n2.電子商務網站系統分析與規劃。'}
# {'date': '01.24', 'JobTitle': '互聯網+智能軟體優秀研發人才(台北/台中)年前卡位，年後SAY YES!', 'company': '鼎新電腦股份有限公司', 'salary': '待遇面議', 'description': '▶攜手打造亞洲矽谷，建構 開放 共享 的智能新局◀\r\n▶運用輕量化虛擬技術打造私有雲平台◀\r\n\r\n☛主動積極，勇於創新、挑戰新事物！\r\n☛樂於分析思考，快速解決問題！\r\n☛重視用戶體...'}
# {'date': '01.24', 'JobTitle': '軟體工程師', 'company': '青松健康事業-青松護理之家', 'salary': '待遇面議', 'description': None}
# {'date': '01.23', 'JobTitle': 'PHP程式設計師', 'company': '捕夢網數位科技有限公司', 'salary': '待遇面議', 'description': '1.使用PHP+Mysql開發網頁應用程式。 \n2.熟悉 PHP + MySQL。 \n3.熟悉 JavaScript。 \n4.需有物件導向觀念。 \n5.熟悉 HTML,CSS 語法。 \n6.熟悉 Linux者佳。 \n7.善於溝通、表達能力...'}
# {'date': '01.23', 'JobTitle': '助理工程師(需輪大夜班)', 'company': '捕夢網數位科技有限公司', 'salary': '待遇面議', 'description': '職務說明:\n1.具備資料庫網頁程式撰寫經驗佳.\n2.熟悉作業系統，Linux 與Windows 管理與維護。\n3.具備網路伺服器(Web、FTP、DNS、Mail)實務架設經驗者佳.\n4.具備程式撰寫能力者佳(PH...'}
# {'date': '01.23', 'JobTitle': '(中和) Android智慧型手機 Framework/APP (軟體) 資深/高級工程師/工程師', 'company': '華冠通訊股份有限公司', 'salary': '待遇面議', 'description': '1. Android phone AP / Framework layer development / integration / debugging\r\r\n2. Customer / Operator SW feature implementation\r\r\n3. C/C++/Java software programming\r\r\n4. 2 years+ experience (nice to ...'}
# {'date': '01.23', 'JobTitle': '尖端所-雲端平台工程師(台中)', 'company': '宏遠興業股份有限公司', 'salary': '未填寫', 'description': '工作單位：智慧穿載電子部門\r\n開發方式: Dreamweaver CS6  等不限\r\n開發項目：雲端管理平台，網站平台，Database存取介面\r\n職務需求：\r\n1. 精通Java語言和物件導向設計方法，熟練掌握J...'}
# {'date': '01.23', 'JobTitle': '尖端所-APP工程師(台中)', 'company': '宏遠興業股份有限公司', 'salary': '未填寫', 'description': None}
# {'date': '01.23', 'JobTitle': '潤泰Fashion Cookie & Corpo網站程式設計師', 'company': '潤泰全球股份有限公司', 'salary': '未填寫', 'description': '1.扎實的 HTML、JavaScript、CSS 知識與技能。\r\n2.Ruby on Rails 網站開發經驗或可學習Ruby on Rails相關技術，\r\n使用過其他 web framework，了解 MVC 架構、習慣物件導向程式設計\r\n3...'}
# {'date': '01.23', 'JobTitle': '[Server]系統軟體工程師(桃園)', 'company': '英業達股份有限公司', 'salary': '未填寫', 'description': '負責產品以及系統之後端程式開發\r\n熟悉Java / RESTful架構者尤佳\r\n有相關經驗者尤佳'}
# {'date': '01.23', 'JobTitle': '[Server]MES 系統開發工程師(上海)', 'company': '英業達股份有限公司', 'salary': '待遇依公司規定', 'description': '1.開發MES 測試、組裝及配銷生產管理系統軟體 \r\n2.開發收集機台生產資料平台及生產資訊分析管理報表\r\n3.收集生產管理需求\r\n4.具備 C#、ASP.NET、Javascript、JQuery、SQL語言 ...'}
# {'date': '01.23', 'JobTitle': '資訊-法金授信系統程式設計師', 'company': '(台新金控)台新國際商業銀行股份有限公司', 'salary': '待遇面議', 'description': '工作內容：法金授信系統開發及維運\r\r\n資格條件：\r\r\n1. 熟悉  Java ,JSP,HTML及SQL語法 \r\r\n2. 具備良好的問題分析解決能力、責任心強、具獨立作業及團隊合作能力'}
# {'date': '01.23', 'JobTitle': 'HTML 5 Programmer', 'company': '益升科技有限公司', 'salary': '待遇依公司規定', 'description': '1. HTML切片和轉換PSD（photoshop圖像）到HTML\n2. 需會HTML 5與CSS 3 \n3. 必須會JQuery 和 Java Script\n4. 能使用PHP優\n5. 另有大夜津貼\n6. 英文程度中等以上'}
# {'date': '01.23', 'JobTitle': 'CIM資訊整合工程師(桃園廠)', 'company': '世界先進積體電路股份有限公司', 'salary': '待遇依公司規定', 'description': '1.FAB 支援生產應用系統開發與維護 2.FAB 資訊相關應用報表開發與維護3.FAB 生產規劃系統開發與維護工作條件：1.大學以上學歷(含)，資訊相關科系所畢，對半導體生產流程有興趣者...'}
# {'date': '01.23', 'JobTitle': 'CIM自動化工程師(新竹廠)', 'company': '世界先進積體電路股份有限公司', 'salary': '待遇面議', 'description': '1.大學以上，資訊工程、機械、電機等相關系所畢2.熟悉Visual Basic, C/C++, Java, SQL, Oracle, Unix, Windows3.具半導體或TFT-LCD廠機台連線,Oracle 程式開發或分散式系統開發經驗...'}
# {'date': '01.22', 'JobTitle': 'GUI人機介面設計工程師(新竹)', 'company': '建漢科技股份有限公司', 'salary': '待遇依公司規定', 'description': '1. 負責Mobile Device [Cell phone, Pad, Tablet...]應用程式的介面流程規劃及設計\r\r\n2. 工作內容:\r\r\n - Familiar with HTML5, HTML, JavaScript, ActionScript 2.0/3.0\r\r\n - 3D drawing, Phot...'}
# {'date': '01.22', 'JobTitle': '工程類(台北)-程式開發工程師', 'company': '可成科技股份有限公司', 'salary': '待遇依公司規定', 'description': '1.熟悉 W3C HTML及相關DHTML技術/CSS語法/DOM模型。\r\n2.熟悉 JavaScript語言。\r\n3.熟悉 ASP.NET VB或C#語言。'}
# {'date': '01.22', 'JobTitle': '工程類-Web 前端工程師', 'company': '可成科技股份有限公司', 'salary': '待遇面議', 'description': '1. 熟悉 HTML/CSS/DOM。 \r\n2. 熟悉Javascript/jQuery/AngularJS/Cordova。\r\n3. 熟悉Agile/DevOps CI CD/Git。'}
# {'date': '01.22', 'JobTitle': 'TC_軟體工程師(技術中心)', 'company': '遠通電收股份有限公司', 'salary': '待遇面議', 'description': '1.因應系統或專案需求進行Java或 .Net 軟體開發及測試\r\r\n2.系統異常分析與處理\r\r\n3.因應需求進行系統調整或精進'}
# {'date': '01.22', 'JobTitle': 'IAS_軟體工程師', 'company': '遠通電收股份有限公司', 'salary': '待遇面議', 'description': '資訊系統開發及介面整合:\r\r\n1.與使用者訪談需求並進行系統及流程設計。\r\r\n2.平日執行資訊系統的日常維運作業。\r\r\n3.進行ETC系統資料分析以作為未來系統調整以及加值服務應用。\r\r\n4.車...'}
# {'date': '01.22', 'JobTitle': 'S.電子商務‧ASP .NET 系統分析師', 'company': '永豐餘消費品實業股份有限公司', 'salary': '待遇面議', 'description': '1.熟悉C#.NET (.NET Framework 2.0以上)。\n2.具有MVC架構、物件導向設計實務專案經驗尤佳。\n3.具 LINQ / Entity Framework 開發經驗尤佳。\n4.熟悉Web(JavaScript、jQuery、Ajax)應...'}
# {'date': '01.22', 'JobTitle': '資深大數據平台開發工程師(台北)【BU68(IQ)-電信EC】', 'company': '敦陽科技股份有限公司', 'salary': '待遇依公司規定', 'description': '1.Hadoop-based應用系統安裝、設定與維護。\r\r\n2.具備2年以上Python + Spark程式設計實務經驗。\r\r\n3.具備Kafka, Hue, Pentaho ETL Tool相關經驗尤佳。\r\r\n4.具備Java基本觀念尤佳。\r\r\n5.樂於...'}
# {'date': '01.22', 'JobTitle': '資訊工程師(網頁開發),無經驗可', 'company': '燿華電子股份有限公司', 'salary': '待遇面議', 'description': '1. Java, Jsp開發作業與維護。 \r\n2. 企業流程系統開發作業與維護。 \r\n3. 企業入口建置與維護。'}
# {'date': '01.22', 'JobTitle': '軟體設計工程師', 'company': '敦陽科技股份有限公司', 'salary': '待遇面議', 'description': '1. 熟悉JSP/Servlet/JDBC/XML/Web Service\r\n2. 使用過任何一種Application Server: WebLogic,JBOSS\r\n3. 網頁技術：HTML,Java Script,AJAX\r\n4. Spring ,Struts,Hibernate等技術框...'}
# {'date': '01.22', 'JobTitle': '大數據平台開發工程師(台北)【BU68(IQ)-電信EC】', 'company': '敦陽科技股份有限公司', 'salary': '待遇面議', 'description': '電信大數據平台程式開發\r\r\n1. 具備Python + Spark程式設計實務經驗。\r\r\n2. 具備Kafka, Hue, Pentaho ETL Tool相關經驗尤佳。 \r\r\n3. 具備Java基本觀念尤佳。 \r\r\n4. 樂於團隊合作、具備良好...'}
# {'date': '01.22', 'JobTitle': 'J2EE 系統設計師 【BU68 電信整合資訊技術開發處】', 'company': '敦陽科技股份有限公司', 'salary': '待遇面議', 'description': '大型電子商務平台/Portal平台/O2O平台/Big Data平台專案系統程式開發:\r\n\r\n工作條件:\r\n\r\n1. 熟悉JSP/Servlet/JDBC/XML/Web Service\r\n\r\n2. 使用過任何一種Application Server: WebLogic...'}
# {'date': '01.22', 'JobTitle': '【松山區】(前期海外受訓)駐點軟體工程師(應屆畢業生可)-21', 'company': '汎亞國際人事顧問股份有限公司', 'salary': '待遇面議', 'description': '工作內容：\n1.負責程式設計、修改、測試及上線。  \n2.負責規劃並執行後台(BackOffice)軟體系統之上線及維護。  \n3.各類技術文件及報告之撰寫。  \n前三個月海外受訓地點：上海\n(來回機票...'}
# {'date': '01.23', 'JobTitle': '尖端所-ERP Engineer(台中)', 'company': '宏遠興業股份有限公司', 'salary': '待遇面議', 'description': '工作單位：智慧穿載電子部門\r\n職務類別：物流ERP-進銷存與財務Engineer\r\n開發方式：JAVA、C#、VB\r\n開發項目：PC軟體\r\n職務內容：\r\n1. 至少熟练掌握一種計算機语言，有web系統開...'}
# {'date': '01.22', 'JobTitle': '新產品軟體開發技術經理/副理/工程師【BU68-IM】', 'company': '敦陽科技股份有限公司', 'salary': '未填寫', 'description': '職務說明：\r\n1.熟Java MVC架構\r\n2.具網站開發經驗\r\n3.應徵技術資深經理需有帶人經驗至少五人以上.'}
# {'date': '01.19', 'JobTitle': '資訊部儲備主管', 'company': '童綜合醫療社團法人童綜合醫院', 'salary': '未填寫', 'description': None}
# {'date': '01.19', 'JobTitle': '資訊部儲備幹部', 'company': '童綜合醫療社團法人童綜合醫院', 'salary': '待遇面議', 'description': None}
# {'date': '01.19', 'JobTitle': 'JSP網頁程式設計師', 'company': '力天資訊科技股份有限公司', 'salary': '待遇面議', 'description': None}
# {'date': '01.19', 'JobTitle': 'Android軟體工程師I', 'company': '矽華軟體有限公司', 'salary': '待遇面議', 'description': '1. 理工科系畢, 軟體程式開發2年以上相關經驗. \n2. MUST HAVE: Java and C++ programming on Android development environment. \n3. OPTIONAL: SQL, C#, Lua, Python, ASP .Net 或自...'}
# {'date': '01.19', 'JobTitle': '資訊儲備幹部(一)', 'company': '臺南紡織股份有限公司', 'salary': '待遇面議', 'description': '1.大學以上資訊相關系所畢\r\r\n2.MIS系統分析、設計與維護\r\r\n3.AS400系統管理\r\r\n4.AS400/CLP、AS400/RPG、Delphi、JAVA、Jcva Script\r\r\n5.DB/400，MS SQL\r\r\n6.Windows各版本\r\r\n7...'}
# {'date': '01.19', 'JobTitle': '網頁視覺設計師(台北)', 'company': '國眾電腦股份有限公司', 'salary': '待遇依公司規定', 'description': '1.   主要工作項目為網頁程式開發\r\n熟悉以下語法：PHP、MySQL、Java Script，熟悉運用CSS3、HTML5、jQuery等 Web 技術製作網頁。\r\n2. 可以具抗壓性，且能獨立作業。\r\n3. 對程式...'}
# {'date': '01.19', 'JobTitle': '自動控制工程師(高雄)', 'company': '國眾電腦股份有限公司', 'salary': '待遇依公司規定', 'description': '1.自控系統專案規劃、執行\r\n2.DDC軟體,圖控軟體程式撰寫\r\n3.JAVA,網頁程式選寫\r\n4.PLC軟體選寫\r\n5.協助業務進行自動化控制系統設計.規劃及估價\r\n6.協助業務作案件開發及客戶情感...'}
# {'date': '01.19', 'JobTitle': '軟體開發工程師(內湖)', 'company': '國眾電腦股份有限公司', 'salary': '待遇依公司規定', 'description': '1. .NET、Java程式撰寫\r\n2. Web開發作業\r\n3. 資料庫應用\r\n4. 金融軟體開發'}
# {'date': '01.18', 'JobTitle': '軟體工程師', 'company': '甘霖有限公司', 'salary': '待遇面議', 'description': '1.負責開發工作流程(BPM or WorkFlow)專案。\n2.熟JavaScript、Java, JSP, SQL 程式撰寫。\n3.負責軟體之分析、設計以及程式撰寫。\n4.無經驗但對軟體開發有高度熱忱者亦可。'}
# {'date': '01.18', 'JobTitle': '程式設計師(有無經驗皆可)', 'company': '甘霖有限公司', 'salary': '待遇面議', 'description': '有JAVA經驗，懂RAD、JSF，WAS，Hibernate等，歡迎具團隊精神，肯學習，負責任，願意投入軟體產業的有志之士，能接受挑戰者，與本公司聯絡。'}
# {'date': '01.18', 'JobTitle': '【松山區】(前期海外培訓)駐點軟體工程師(應屆畢業生可)-21', 'company': '汎亞國際人事顧問股份有限公司', 'salary': '待遇面議', 'description': '工作內容：\n1.負責程式設計、修改、測試及上線。  \n2.負責規劃並執行後台(BackOffice)軟體系統之上線及維護。  \n3.各類技術文件及報告之撰寫。  \n前三個月海外受訓地點：上海\n(來回機票...'}
# {'date': '01.18', 'JobTitle': '軟體顧問師', 'company': '(GD-CRM)通用數碼股份有限公司', 'salary': '待遇面議', 'description': '1). 協助客戶進行GD-CRM系統導入之專案規劃、進度控管、上線輔導、技術移轉、個案需求分析與設計。\n(2). 協助客戶解決GD-CRM系統運作所遭遇之各種操作及應用問題。\n\n需具備之經...'}
# {'date': '01.18', 'JobTitle': '軟體服務工程師', 'company': '(GD-CRM)通用數碼股份有限公司', 'salary': '待遇依公司規定', 'description': '(1). 系統問題排除。\n(2). 系統版本更新維護。\n(3). 客製化程式撰寫與維護。 \n(4). 系統安裝。\n\n需具備：\n(1)基本專業技能需求：HTML、SQL Server、Java Script、C#.Net\n(2)具備網頁程...'}
# {'date': '01.18', 'JobTitle': '程式設計師', 'company': '莫絲皮件護理棧', 'salary': '待遇依公司規定', 'description': '1.資料庫系統設計、管理、維護能力\n2.軟體工程的開發、設計、整合測試\n3.熟悉並撰寫網頁語法 \n4.網路程式設計\n電腦技能：程式設計：PHP\n資料庫：MySQL\n網頁技術：HTML／Java Sc...'}
# {'date': '01.18', 'JobTitle': 'Linux kernel/device driver development Engineer/主管 - J0394', 'company': '廣達電腦股份有限公司', 'salary': '待遇面議', 'description': None}
# {'date': '01.18', 'JobTitle': '自動化程式開發主管/專員 - J0168', 'company': '廣達電腦股份有限公司', 'salary': '待遇依公司規定', 'description': '1. Server/Storage/Networking Validation automation development by Java, Python, Linux Bash or Windows Powershell\r\r\n2. System analysis on validation automation requirements and project/ schedule deve...'}
# {'date': '01.18', 'JobTitle': '應用軟體工程師-(工作地點:台北市民生科技大樓)', 'company': '康舒科技股份有限公司', 'salary': '待遇面議', 'description': '康舒科技的前瞻技術研究中心現在在尋找資訊工程或相關科系的軟體開發人才。你將會開發智慧電表的後台系統。\n\n我們希望應徵者能具有下列特性:\n●具有團隊精神\n●解決問題的邏輯思考\n...'}
# {'date': '01.19', 'JobTitle': '網頁設計管理人員', 'company': '九九行國際有限公司', 'salary': '待遇依公司規定', 'description': '1..熟悉電腦修圖與影像合成。\n2..擅長網頁設計、平面廣告設計經驗(請務必附作品參考) 。\n具網頁設計相關經驗，HTML、CSS/DIV切版，JavaScript、jQuery，熟悉語言架構，解決各種...'}
# {'date': '01.17', 'JobTitle': 'Android應用工程師(內湖)－71101', 'company': '精技電腦股份有限公司', 'salary': '待遇面議', 'description': '[工作內容]\n1.負青開發應用企業營運之Android APP\n2.研究新技術與新工具，公司亦會主動規畫參與研討會及教育訓練\n\n \n[ 專長與特質 ]\n1. 熟悉Java、Android SDK、框架運作原理、SQLi...'}
# {'date': '01.17', 'JobTitle': 'PHP 程式設計師─71101', 'company': '精技電腦股份有限公司', 'salary': '未填寫', 'description': '[工作內容]\n負責PHP 網頁應用程式之開發與維護\n\n[技能]\n1.有學習過PHP網頁語言、資料庫及 SQL 語法、HTML及CSS 語法\n2.有JavaScript 應用經驗更佳'}
# {'date': '01.17', 'JobTitle': 'php網路程式設計師', 'company': '欣揚科技有限公司', 'salary': '未填寫', 'description': '1. 熟悉 PHP 程式語言。\n2. 熟悉 MySQL 資料庫。\n3. 瞭解 HTML 、 Java Script 、 CSS 、 jQuery 等Web技術。\n4. 重視team work'}
# {'date': '01.18', 'JobTitle': '軟體維護工程師', 'company': '甘霖有限公司', 'salary': '待遇面議', 'description': '1.維護公司現有各項產品與服務之相關軟體(JAVA Base)\n2.不需業務開發、不需有豐富經驗，本公司會培訓\n3.客戶多，主要處理企業軟體使用相關問題(可連結網頁)\n企業網址 ： http://www.as...'}
# {'date': '01.16', 'JobTitle': 'ASP.NET MVC軟體工程師', 'company': '一訂科技股份有限公司', 'salary': '待遇面議', 'description': '所需技術\n前端：HTML5 + CSS3 + Bootstrap + Java Script + jQuery +  (AJAX) + AngularJS\n後端：MVC + WEB API + Entity Framework + MS SQL 2008 以上\n版控：Microsoft Team S...'}
# {'date': '01.16', 'JobTitle': 'PHP網頁後端工程師', 'company': '富比庫股份有限公司', 'salary': '待遇面議', 'description': '1.後端網頁設計開發與維護\n2.熟悉PHP、MySQL、Javascript、等Web開發能力。\n3.了解關聯式資料庫的概念。\n4.使用Framework 共同開發'}
# {'date': '01.16', 'JobTitle': '網路程式設計師', 'company': '(大當家聯合網)成商數位整合有限公司', 'salary': '待遇面議', 'description': '帶著您的網頁設計創意來吧!!\n我們重視團隊合作的觀念並堅持以使用者體驗為優先考量，\n如果你想要有個一展長才的機會，\n能夠成為網頁程式設計的佼佼者，\n那就不要錯過機會，快來加入...'}
# {'date': '01.16', 'JobTitle': '行動裝置APP程式設計師', 'company': '展輝科技股份有限公司', 'salary': '待遇面議', 'description': '1.Android/IOS APP開發\n2.程式語言：HTML/CSS/JavaScript/Jquery(有C#基礎及熟悉ASP.NET MVC開發者佳)\n3.開發工具：Visual Studio Apache Cordova /MS SQL\n4.善於溝通表達...'}
# {'date': '01.16', 'JobTitle': 'Internet程式設計師', 'company': '展輝科技股份有限公司', 'salary': '待遇面議', 'description': '1.資訊管理系統與網站開發(有RWD基礎者佳)\n2.程式語言：C#/ASP.NET MVC/JavaScript/Jquery\n3.開發工具：Visual Studio/MS SQL\n4.善於溝通表達與團隊合作，歡迎主動積極的你一...'}
# {'date': '01.15', 'JobTitle': 'HK-軟體工程師(工作地：香港)', 'company': '緯創軟體股份有限公司', 'salary': '待遇面議', 'description': '1. 至香港客戶端環境開發工作。\r\r\n2. 手機/平板平台語音互動軟體開發。\r\r\n3. 所需條件\r\r\n    ●Know Java, and/or a major programming language; \r\r\n    ●Comfortable with Terminal/bash \r\r\n    ●B...'}
# {'date': '01.15', 'JobTitle': 'R-Front-End Developer', 'company': '緯創軟體股份有限公司', 'salary': '待遇面議', 'description': '1. Write clean, modern JavaScript code to create fantastic and user-friendly \r\r\n     experiences \r\r\n2. You will be using modern frameworks and technologies such as Angular.js or Electron and more to crea...'}
# {'date': '01.15', 'JobTitle': 'R-前端工程師 (AngularJS)', 'company': '緯創軟體股份有限公司', 'salary': '待遇面議', 'description': '1.Responsible for design, coding, unittesting, review and implementation \r\r\n   application and services by using Java Enterprise Application framework \r\r\n   such as Spring, Hibernate, JPA, Spring Bo...'}
# {'date': '01.15', 'JobTitle': 'R-大數據資料分析師', 'company': '緯創軟體股份有限公司', 'salary': '待遇面議', 'description': '1. 因應客戶對大數據之需求進行開發，操作、監測ETL數據。\r\r\n2. 使用ETL進行蒐集、清洗。\r\r\n3. 使用SSIS…等工具處理資料，並以Hadoop…等工具儲存並支援數據分析任務。\r\r\n4. 依...'}
# {'date': '01.15', 'JobTitle': 'R-MES (Location : Taipei)', 'company': '緯創軟體股份有限公司', 'salary': '待遇面議', 'description': '1.Be able to travel or on-site Taichung, Tainan,China flexiblly  \r\n2.Fmailiar with Java, C#, VB.NET (at lease 2 yrs) \r\n3.Bachelor degree or above in CE/CS/CIS releated major \r\n4.Be willing...'}
# {'date': '01.15', 'JobTitle': '軟體工程師', 'company': '子辰國際開發股份有限公司', 'salary': '未填寫', 'description': '1. 具備 Java、HTML、CSS、Javascript 網頁技術相關經驗\n2. 孰悉MySQL語法\n3. 樂於溝通與積極學習\n'}
# {'date': '01.11', 'JobTitle': '竹南02H_資訊-(助理)工程師', 'company': '微矽電子股份有限公司', 'salary': '未填寫', 'description': '1、JAVA程式開發。\n2、維護公司網路系統。\n3、其它交辦事項'}
# {'date': '01.05', 'JobTitle': '網路平台開發RD工程師', 'company': '沛盛資訊有限公司', 'salary': '未填寫', 'description': '喜愛研發設計，熟ASP‧Net程式設計，熟C#或VB.Net等語言，有網站程式設計經驗者，對AI、大數據分析有興趣，對設計軟體雲端產品設計有熱誠及熟 JavaScript/CSS3、 RWD、資料...'}

# %%
import pandas as pd
df = pd.DataFrame(datas)
df
# Out:
#                                              JobTitle                 company  \
# 0                                 D4000 網站開發工程師(Java)            富邦媒體科技股份有限公司
# 1                                D4000 大數據平台工程師(Java)            富邦媒體科技股份有限公司
# 2                              D4000 MIS程式開發工程師(JAVA)            富邦媒體科技股份有限公司
# 3                              D4000 網站開發工程師(Java)-台中            富邦媒體科技股份有限公司
# 4                                 D4000 系統開發架構師(JAVA)            富邦媒體科技股份有限公司
# 5                                           JAVA程式設計師             捕夢網數位科技有限公司
# 6                                         JAVA資深程式設計師          遠雄人壽保險事業股份有限公司
# 7                                       Java軟體工程師(LT)  (PChome)網路家庭國際資訊股份有限公司
# 8                                      Java工程師(B0203)  (PChome)網路家庭國際資訊股份有限公司
# 9                               JAVA工程師 (支付服務)(E0804)  (PChome)網路家庭國際資訊股份有限公司
# 10                                       資訊-Java程式設計師    (台新金控)台新國際商業銀行股份有限公司
# 11                               資訊-Java資深程式設計師(影像系統)    (台新金控)台新國際商業銀行股份有限公司
# 12                              資訊-Java程式設計師(網銀/電子支付)    (台新金控)台新國際商業銀行股份有限公司
# 13                                            Java工程師              萬海航運股份有限公司
# 14                                工程類(台北)-Java IOT工程師              可成科技股份有限公司
# 15            資深Java/J2EE程式設計師 (台北)【BU68-電信整合資訊技術開發處】              敦陽科技股份有限公司
# 16          約聘 軟體工程師 (Java or C#) (新竹)【BU2-BTB】【敦陽資訊】              敦陽科技股份有限公司
# 17                   JavaScript/JQuery 程式互動設計師(B0202)  (PChome)網路家庭國際資訊股份有限公司
# 18                           C3811 電子錢包 Java(資深)開發工程師              遠傳電信股份有限公司
# 19                         I3101 應收管理系統工程師 (板橋,熟Java)              遠傳電信股份有限公司
# 20                        C3811 Java開發 工程師(內湖)_電子金流平台              遠傳電信股份有限公司
# 21                    C3811 Java開發 (資深)工程師(內湖)_電子金流平台              遠傳電信股份有限公司
# 22                                 C3111 Java開發 資深工程師              遠傳電信股份有限公司
# 23                              C3811 Java開發 技術副理(內湖)              遠傳電信股份有限公司
# 24                                       R-Java SD/PG              緯創軟體股份有限公司
# 25                         R-Java Full Stack Dev Lead              緯創軟體股份有限公司
# 26                                          JAVA系統設計師                女子徵信有限公司
# 27                                            程式設計工程師              旭德科技股份有限公司
# 28                                       ☄ PHP程式設計師 ☄              中美國際教育有限公司
# 29                             資訊管理類-MIS儲備幹部(深圳廠或崑山廠)              凌巨科技股份有限公司
# ..                                                ...                     ...
# 64                                        網頁視覺設計師(台北)              國眾電腦股份有限公司
# 65                                        自動控制工程師(高雄)              國眾電腦股份有限公司
# 66                                        軟體開發工程師(內湖)              國眾電腦股份有限公司
# 67                                              軟體工程師                  甘霖有限公司
# 68                                      程式設計師(有無經驗皆可)                  甘霖有限公司
# 69                    【松山區】(前期海外培訓)駐點軟體工程師(應屆畢業生可)-21          汎亞國際人事顧問股份有限公司
# 70                                              軟體顧問師      (GD-CRM)通用數碼股份有限公司
# 71                                            軟體服務工程師      (GD-CRM)通用數碼股份有限公司
# 72                                              程式設計師                 莫絲皮件護理棧
# 73  Linux kernel/device driver development Enginee...              廣達電腦股份有限公司
# 74                               自動化程式開發主管/專員 - J0168              廣達電腦股份有限公司
# 75                           應用軟體工程師-(工作地點:台北市民生科技大樓)              康舒科技股份有限公司
# 76                                           網頁設計管理人員               九九行國際有限公司
# 77                             Android應用工程師(內湖)－71101              精技電腦股份有限公司
# 78                                    PHP 程式設計師─71101              精技電腦股份有限公司
# 79                                         php網路程式設計師                欣揚科技有限公司
# 80                                            軟體維護工程師                  甘霖有限公司
# 81                                   ASP.NET MVC軟體工程師              一訂科技股份有限公司
# 82                                         PHP網頁後端工程師               富比庫股份有限公司
# 83                                            網路程式設計師      (大當家聯合網)成商數位整合有限公司
# 84                                       行動裝置APP程式設計師              展輝科技股份有限公司
# 85                                      Internet程式設計師              展輝科技股份有限公司
# 86                                   HK-軟體工程師(工作地：香港)              緯創軟體股份有限公司
# 87                              R-Front-End Developer              緯創軟體股份有限公司
# 88                                R-前端工程師 (AngularJS)              緯創軟體股份有限公司
# 89                                         R-大數據資料分析師              緯創軟體股份有限公司
# 90                          R-MES (Location : Taipei)              緯創軟體股份有限公司
# 91                                              軟體工程師            子辰國際開發股份有限公司
# 92                                   竹南02H_資訊-(助理)工程師              微矽電子股份有限公司
# 93                                        網路平台開發RD工程師                沛盛資訊有限公司
#
#      date                                        description   salary
# 0   01.24                1.Java 網站程式開發與維護。
# 2.電子商務網站系統分析與規劃。  待遇依公司規定
# 1   01.24  1.JAVA大數據平台開發和維運。
# 2.大數據開源(open source)方案研究。
# 3....     待遇面議
# 2   01.24    1.電子表單系統JAVA程式開發與系統維護。
# 2.協助表單系統分析、規劃、測試及流程改善優化。  待遇依公司規定
# 3   01.24                 1.Java 網站程式開發與維護。
# 2.電子商務網站系統分析與規劃。  待遇依公司規定
# 4   01.24  1.Java 系統架構規劃。
# 2.Java 新技術之研究。
# 3.Java Web Appli...     待遇面議
# 5   01.23  1.Java軟體平台開發
# 2.熟悉Java SE/Java EE 程式設計與開發
# 3.熟...  待遇依公司規定
# 6   01.23                 1.負責Java應用系統開發及維護。
# 2.負責各項專案開發及執行。
#   待遇依公司規定
# 7   01.23                                           Java程式開發  待遇依公司規定
# 8   01.23                                           程式撰寫Java  待遇依公司規定
# 9   01.23                                            程式開發與維護     待遇面議
# 10  01.23  工作內容：
#
# 1.偕同廠商與使用者進行需求訪談
#
# 2.境外高資產客戶平台建置維運作業
#
# ...     待遇面議
# 11  01.23                                               None     待遇面議
# 12  01.23  1.網路銀行、電子支付平台需求訪談及交易程式開發
#
# 2.參與需求訪談，進行系統分析/設計/...  待遇依公司規定
# 13  01.22       1. 負責Java/app程式設計、編碼、測試、實施及維護
# 2. 網站相關產品及資料維護  待遇依公司規定
# 14  01.22  1. Raspberry Pi on Android Things or ubuntu。
# ...     待遇面議
# 15  01.22  大型電子商務平台/Portal平台/O2O平台/Big Data平台專案系統程式開發:
#
# ...     待遇面議
# 16  01.22  工作內容：
#
# 1. 負責軟體程式撰寫（前、後端）。
#
# 2. 進行軟體之測試與修改。
#
# ...  待遇依公司規定
# 17  01.23                                             網頁製作設計     待遇面議
# 18  01.18  主要負責friDAY電子錢包系統相關事宜:
#
# 1.配合加值服務產品的上線計劃，支援開發工...     待遇面議
# 19  01.18  此職位主要負責帳務系統相關領域之工作, 其工作內容如下:
#
# 1.使用者需求收集及分析
# ...      未填寫
# 20  01.18  負責加值服務平台軟體之分析、設計以及程式開發,工作內容為:
#
# - 平台上線前測試
# - ...     待遇面議
# 21  01.18  To be a task force leader and executor within ...     待遇面議
# 22  01.18  (1)Java 開發工程師
# (2)具備 Internet OTT 服務 or 影音服務平...     待遇面議
# 23  01.18  A technical assistant manager to lead the team...     待遇面議
# 24  01.15  1. 負責金融/電信/製造業/IT/電子等專案系統之分析、設計以及程式撰寫。
# 2. 規劃執...     待遇面議
# 25  01.15  WistronITS is  looking  for  intelligent,  cre...     待遇面議
# 26  01.02  1.製程改善，良率提升，製程監控，專案執行
# 2.與客戶或公司的硬體部門的同仁共同研發或解決問...     待遇面議
# 27  01.24  1. 軟體設計與程式撰寫。
#
# 2. 負責 Webform、Winform、APP 程式開發...  待遇依公司規定
# 28  01.24  1.管理伺服器,基本網路及電腦問題處理。
# 2.熟悉 PHP 程式設計、JQuery 及 M...  待遇依公司規定
# 29  01.24          1.負責開發.NET、Java、Oracle DB 任一相關軟體。
# 2.儲備主管  待遇依公司規定
# ..    ...                                                ...      ...
# 64  01.19  1.   主要工作項目為網頁程式開發
# 熟悉以下語法：PHP、MySQL、Java Scri...  待遇依公司規定
# 65  01.19  1.自控系統專案規劃、執行
# 2.DDC軟體,圖控軟體程式撰寫
# 3.JAVA,網頁程式選寫...  待遇依公司規定
# 66  01.19  1. .NET、Java程式撰寫
# 2. Web開發作業
# 3. 資料庫應用
# 4. 金融軟體開發  待遇依公司規定
# 67  01.18  1.負責開發工作流程(BPM or WorkFlow)專案。
# 2.熟JavaScript、J...     待遇面議
# 68  01.18  有JAVA經驗，懂RAD、JSF，WAS，Hibernate等，歡迎具團隊精神，肯學習，負責...     待遇面議
# 69  01.18  工作內容：
# 1.負責程式設計、修改、測試及上線。
# 2.負責規劃並執行後台(BackOff...     待遇面議
# 70  01.18  1). 協助客戶進行GD-CRM系統導入之專案規劃、進度控管、上線輔導、技術移轉、個案需求分...     待遇面議
# 71  01.18  (1). 系統問題排除。
# (2). 系統版本更新維護。
# (3). 客製化程式撰寫與維護。
# ...  待遇依公司規定
# 72  01.18  1.資料庫系統設計、管理、維護能力
# 2.軟體工程的開發、設計、整合測試
# 3.熟悉並撰寫網頁語...  待遇依公司規定
# 73  01.18                                               None     待遇面議
# 74  01.18  1. Server/Storage/Networking Validation automa...  待遇依公司規定
# 75  01.18  康舒科技的前瞻技術研究中心現在在尋找資訊工程或相關科系的軟體開發人才。你將會開發智慧電表的後...     待遇面議
# 76  01.19  1..熟悉電腦修圖與影像合成。
# 2..擅長網頁設計、平面廣告設計經驗(請務必附作品參考) 。...  待遇依公司規定
# 77  01.17  [工作內容]
# 1.負青開發應用企業營運之Android APP
# 2.研究新技術與新工具，公司...     待遇面議
# 78  01.17  [工作內容]
# 負責PHP 網頁應用程式之開發與維護
#
# [技能]
# 1.有學習過PHP網頁語言、...      未填寫
# 79  01.17  1. 熟悉 PHP 程式語言。
# 2. 熟悉 MySQL 資料庫。
# 3. 瞭解 HTML 、 ...      未填寫
# 80  01.18  1.維護公司現有各項產品與服務之相關軟體(JAVA Base)
# 2.不需業務開發、不需有豐富...     待遇面議
# 81  01.16  所需技術
# 前端：HTML5 + CSS3 + Bootstrap + Java Script...     待遇面議
# 82  01.16  1.後端網頁設計開發與維護
# 2.熟悉PHP、MySQL、Javascript、等Web開發能...     待遇面議
# 83  01.16  帶著您的網頁設計創意來吧!!
# 我們重視團隊合作的觀念並堅持以使用者體驗為優先考量，
# 如果你想...     待遇面議
# 84  01.16  1.Android/IOS APP開發
# 2.程式語言：HTML/CSS/JavaScript...     待遇面議
# 85  01.16  1.資訊管理系統與網站開發(有RWD基礎者佳)
# 2.程式語言：C#/ASP.NET MVC/...     待遇面議
# 86  01.15  1. 至香港客戶端環境開發工作。
#
# 2. 手機/平板平台語音互動軟體開發。
#
# 3. 所需...     待遇面議
# 87  01.15  1. Write clean, modern JavaScript code to crea...     待遇面議
# 88  01.15  1.Responsible for design, coding, unittesting,...     待遇面議
# 89  01.15  1. 因應客戶對大數據之需求進行開發，操作、監測ETL數據。
#
# 2. 使用ETL進行蒐集、...     待遇面議
# 90  01.15  1.Be able to travel or on-site Taichung, Taina...     待遇面議
# 91  01.15  1. 具備 Java、HTML、CSS、Javascript 網頁技術相關經驗
# 2. 孰悉M...      未填寫
# 92  01.11                   1、JAVA程式開發。
# 2、維護公司網路系統。
# 3、其它交辦事項      未填寫
# 93  01.05  喜愛研發設計，熟ASP‧Net程式設計，熟C#或VB.Net等語言，有網站程式設計經驗者，對...      未填寫
#
# [94 rows x 5 columns]

# %%
print(df.shape)
# Out:
# (94, 5)

# %%
print(df.describe())
# Out:
#        JobTitle     company   date                          description salary
# count        94          94     94                                   87     94
# unique       92          47     11                                   84      3
# top       軟體工程師  敦陽科技股份有限公司  01.23  1.Java 網站程式開發與維護。
# 2.電子商務網站系統分析與規劃。   待遇面議
# freq          3           7     22                                    2     56

# %%
import sqlite3
import pymysql

# %%
# , charset="utf8"

conn = pymysql.connect(host='localhost', port=3306, user='root', password='1234', db='yes123', use_unicode=True, charset="utf8")

# %%
cur = conn.cursor()

# %%
cur.execute("""CREATE TABLE JAVA (
date VARCHAR(255),
JobTitle VARCHAR(255),
company VARCHAR(255),
salary VARCHAR(255),
description VARCHAR(1255)
)""")
conn.commit()

# %%
for row in datas:
    #print(row)
    #cur.execute("""INSERT INTO tablename VALUES (?, ?, ?, ?, ?)""", (val1, val2, val3, val4, val5))
    cur.execute("""INSERT INTO JAVA VALUES (%s, %s, %s, %s, %s)""",
                         (row['date'],
                          row['JobTitle'],
                          row['company'],
                          row['salary'],
                          row['description'])
                        )
conn.commit()

# %%
conn.close()

# %%
cur.execute("""DROP TABLE JAVA""")
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-10-2c4675996dca> in <module>()
# ----> 1 cur.execute("""DROP TABLE JAVA""")
#       2 conn.commit()
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     163         query = self.mogrify(query, args)
#     164
# --> 165         result = self._query(query)
#     166         self._executed = query
#     167         return result
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     319         conn = self._get_db()
#     320         self._last_executed = q
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     858                 sql = sql.encode(self.encoding, 'surrogateescape')
#     859         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 860         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     861         return self._affected_rows
#     862
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1059         else:
#    1060             result = MySQLResult(self)
# -> 1061             result.read()
#    1062         self._result = result
#    1063         if result.server_status is not None:
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1347     def read(self):
#    1348         try:
# -> 1349             first_packet = self.connection._read_packet()
#    1350
#    1351             if first_packet.is_ok_packet():
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1016
#    1017         packet = packet_type(buff, self.encoding)
# -> 1018         packet.check_error()
#    1019         return packet
#    1020
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pymysql/connections.py in check_error(self)
#     382             errno = self.read_uint16()
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#     386     def dump(self):
#
# ~/.pyenv/versions/3.6.1/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     105         errval = data[3:].decode('utf-8', 'replace')
#     106     errorclass = error_map.get(errno, InternalError)
# --> 107     raise errorclass(errno, errval)
#
# InternalError: (1051, "Unknown table 'yes123.JAVA'")
